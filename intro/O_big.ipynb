# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.special

# %%
x = np.linspace(1, 100)
square_stepen = x ** 2
log_stepen_2 = np.log2(x) ** 2
koren_log = np.sqrt(np.log2(x))
n_div_log_base_5 = x / (np.log(x) / np.log(5))
koren = np.sqrt(x)
log_fact = np.log2(scipy.special.factorial(x))
fact = scipy.special.factorial(x)
stepen_2_stepen_2 = 2 ** (2 ** x)
# Out:
# c:\users\skaat\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# c:\users\skaat\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in power
#   if __name__ == '__main__':

# %%
x = np.linspace(1, 10000000000000000000000000)
first = np.log2(x) ** 2
second = np.sqrt(x)
plt.plot(first, label='first')
plt.plot(second, label='second')
plt.legend()

# %%
2 ** (np.log2(x ** 2))
# Out:
# array([1.00000000e+00, 1.06132045e+04, 4.20417364e+04, 9.42865956e+04,
#        1.67347782e+05, 2.61225296e+05, 3.75919137e+05, 5.11429306e+05,
#        6.67755802e+05, 8.44898626e+05, 1.04285778e+06, 1.26163325e+06,
#        1.50122506e+06, 1.76163319e+06, 2.04285765e+06, 2.34489844e+06,
#        2.66775556e+06, 3.01142900e+06, 3.37591877e+06, 3.76122486e+06,
#        4.16734729e+06, 4.59428604e+06, 5.04204112e+06, 5.51061253e+06,
#        6.00000026e+06, 6.51020432e+06, 7.04122471e+06, 7.59306143e+06,
#        8.16571447e+06, 8.75918384e+06, 9.37346954e+06, 1.00085716e+07,
#        1.06644899e+07, 1.13412246e+07, 1.20387756e+07, 1.27571429e+07,
#        1.34963266e+07, 1.42563266e+07, 1.50371429e+07, 1.58387756e+07,
#        1.66612245e+07, 1.75044898e+07, 1.83685714e+07, 1.92534694e+07,
#        2.01591837e+07, 2.10857143e+07, 2.20330612e+07, 2.30012245e+07,
#        2.39902041e+07, 2.50000000e+07])

# %%
first
# Out:
# array([1.00000000e+00, 1.06132045e+04, 4.20417364e+04, 9.42865956e+04,
#        1.67347782e+05, 2.61225296e+05, 3.75919137e+05, 5.11429306e+05,
#        6.67755802e+05, 8.44898626e+05, 1.04285778e+06, 1.26163325e+06,
#        1.50122506e+06, 1.76163319e+06, 2.04285765e+06, 2.34489844e+06,
#        2.66775556e+06, 3.01142900e+06, 3.37591877e+06, 3.76122486e+06,
#        4.16734729e+06, 4.59428604e+06, 5.04204112e+06, 5.51061253e+06,
#        6.00000026e+06, 6.51020432e+06, 7.04122471e+06, 7.59306143e+06,
#        8.16571447e+06, 8.75918384e+06, 9.37346954e+06, 1.00085716e+07,
#        1.06644899e+07, 1.13412246e+07, 1.20387756e+07, 1.27571429e+07,
#        1.34963266e+07, 1.42563266e+07, 1.50371429e+07, 1.58387756e+07,
#        1.66612245e+07, 1.75044898e+07, 1.83685714e+07, 1.92534694e+07,
#        2.01591837e+07, 2.10857143e+07, 2.20330612e+07, 2.30012245e+07,
#        2.39902041e+07, 2.50000000e+07])

# %%
plt.plot(log_stepen_2, label='log_stepen_2')
# plt.plot(square_stepen,  label='square_stepen')
# plt.plot(fact, label='log_fact')
plt.plot(koren, label='koren')
# plt.plot(koren_log, label='koren_log')
# plt.plot(n_div_log_base_5, label='n_div_log_base_5')
# plt.plot(fact / stepen )
plt.legend()

# %%
sem_log_2n = 3 ** (np.log2(x))

# plt.plot(stepen_2_stepen_2, label='stepen_2_stepen_2')
plt.plot(log_fact, label='log_fact')
plt.plot(sem_log_2n, label='sem_log_2n')
plt.legend()
